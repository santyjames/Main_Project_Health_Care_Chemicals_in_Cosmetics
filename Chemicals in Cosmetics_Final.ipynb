# %% [markdown]
# <h1 style="color:Red;">Chemicals in Cosmetics</h1>

# %% [markdown]
# <h2 style="color: blue; text-decoration: underline;">
# Objective
# </h2>

# %% [raw]
# To analyze the California Safe Cosmetics Program dataset using Python to identify cosmetic products and brands containing potentially harmful chemical ingredients reported to the California Department of Public Health

# %%
import pandas as pd # importing Pandas Libraray

# %%
df=pd.read_csv(r'C:\Users\User\Desktop\Data Analyst\Final Project\Dataset_Health_Care\Chemicals in Cosmetics\cscpopendata.csv') #Load Dataset

# %%
df
# Out:
#         CDPHId                                        ProductName    CSFId  \
# 0            2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES      NaN
# 1            3                         Glover's Medicated Shampoo      NaN
# 2            3                         Glover's Medicated Shampoo      NaN
# 3            4           PRECISION GLIMMER EYE LINER-ALL SHADES �      NaN
# 4            5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �      NaN
# ...        ...                                                ...      ...
# 114630   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65001.0
# 114631   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65002.0
# 114632   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65003.0
# 114633   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65004.0
# 114634   41524  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...      NaN
#
#                  CSF  CompanyId                   CompanyName  BrandName  \
# 0                NaN          4                  New Avon LLC       AVON
# 1                NaN        338           J. Strickland & Co.   Glover's
# 2                NaN        338           J. Strickland & Co.   Glover's
# 3                NaN          4                  New Avon LLC       AVON
# 4                NaN          4                  New Avon LLC       AVON
# ...              ...        ...                           ...        ...
# 114630     Rosa Soft       1259               Yanbal USA, Inc     YANBAL
# 114631  Malva Spirit       1259               Yanbal USA, Inc     YANBAL
# 114632  Rojo Fashion       1259               Yanbal USA, Inc     YANBAL
# 114633  Terra Mystic       1259               Yanbal USA, Inc     YANBAL
# 114634           NaN         86  The Procter & Gamble Company  Old Spice
#
#         PrimaryCategoryId                    PrimaryCategory  SubCategoryId  \
# 0                      44    Makeup Products (non-permanent)             53
# 1                      18  Hair Care Products (non-coloring)             25
# 2                      18  Hair Care Products (non-coloring)             25
# 3                      44    Makeup Products (non-permanent)             46
# 4                      44    Makeup Products (non-permanent)             52
# ...                   ...                                ...            ...
# 114630                 44    Makeup Products (non-permanent)             53
# 114631                 44    Makeup Products (non-permanent)             53
# 114632                 44    Makeup Products (non-permanent)             53
# 114633                 44    Makeup Products (non-permanent)             53
# 114634                  6                      Bath Products            159
#
#         ...   CasNumber  ChemicalId            ChemicalName  \
# 0       ...  13463-67-7           6        Titanium dioxide
# 1       ...  65996-92-1           4  Distillates (coal tar)
# 2       ...    140-67-0           5               Estragole
# 3       ...  13463-67-7           7        Titanium dioxide
# 4       ...  13463-67-7           8        Titanium dioxide
# ...     ...         ...         ...                     ...
# 114630  ...  13463-67-7       68059        Titanium dioxide
# 114631  ...  13463-67-7       68060        Titanium dioxide
# 114632  ...  13463-67-7       68061        Titanium dioxide
# 114633  ...  13463-67-7       68062        Titanium dioxide
# 114634  ...  13463-67-7       68074        Titanium dioxide
#
#         InitialDateReported MostRecentDateReported DiscontinuedDate  \
# 0                06/17/2009             08/28/2013       02/01/2011
# 1                07/01/2009             07/01/2009              NaN
# 2                07/01/2009             07/01/2009              NaN
# 3                07/09/2009             08/28/2013              NaN
# 4                07/09/2009             08/28/2013       02/01/2011
# ...                     ...                    ...              ...
# 114630           06/19/2020             06/19/2020              NaN
# 114631           06/19/2020             06/19/2020              NaN
# 114632           06/19/2020             06/19/2020              NaN
# 114633           06/19/2020             06/19/2020              NaN
# 114634           06/23/2020             06/23/2020              NaN
#
#        ChemicalCreatedAt ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 0             07/09/2009        07/09/2009                 NaN             1
# 1             07/01/2009        07/01/2009                 NaN             2
# 2             07/02/2009        07/02/2009                 NaN             2
# 3             07/09/2009        07/09/2009                 NaN             1
# 4             07/09/2009        07/09/2009                 NaN             1
# ...                  ...               ...                 ...           ...
# 114630        06/19/2020        06/19/2020                 NaN             1
# 114631        06/19/2020        06/19/2020                 NaN             1
# 114632        06/19/2020        06/19/2020                 NaN             1
# 114633        06/19/2020        06/19/2020                 NaN             1
# 114634        06/23/2020        06/23/2020                 NaN             1
#
# [114635 rows x 22 columns]

# %%
df.shape # Dimensions of a DataFrame.
# Out:
# (114635, 22)

# %%
df.dtypes #Data Type of each column
# Out:
# CDPHId                      int64
# ProductName                object
# CSFId                     float64
# CSF                        object
# CompanyId                   int64
# CompanyName                object
# BrandName                  object
# PrimaryCategoryId           int64
# PrimaryCategory            object
# SubCategoryId               int64
# SubCategory                object
# CasId                       int64
# CasNumber                  object
# ChemicalId                  int64
# ChemicalName               object
# InitialDateReported        object
# MostRecentDateReported     object
# DiscontinuedDate           object
# ChemicalCreatedAt          object
# ChemicalUpdatedAt          object
# ChemicalDateRemoved        object
# ChemicalCount               int64
# dtype: object

# %%
df.info() # Concise summary of a Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114635 entries, 0 to 114634
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CDPHId                  114635 non-null  int64
#  1   ProductName             114635 non-null  object
#  2   CSFId                   80662 non-null   float64
#  3   CSF                     80237 non-null   object
#  4   CompanyId               114635 non-null  int64
#  5   CompanyName             114635 non-null  object
#  6   BrandName               114408 non-null  object
#  7   PrimaryCategoryId       114635 non-null  int64
#  8   PrimaryCategory         114635 non-null  object
#  9   SubCategoryId           114635 non-null  int64
#  10  SubCategory             114635 non-null  object
#  11  CasId                   114635 non-null  int64
#  12  CasNumber               108159 non-null  object
#  13  ChemicalId              114635 non-null  int64
#  14  ChemicalName            114635 non-null  object
#  15  InitialDateReported     114635 non-null  object
#  16  MostRecentDateReported  114635 non-null  object
#  17  DiscontinuedDate        12920 non-null   object
#  18  ChemicalCreatedAt       114635 non-null  object
#  19  ChemicalUpdatedAt       114635 non-null  object
#  20  ChemicalDateRemoved     2985 non-null    object
#  21  ChemicalCount           114635 non-null  int64
# dtypes: float64(1), int64(7), object(14)
# memory usage: 19.2+ MB

# %%
df.columns=(df.columns.str.strip()) #used to remove leading and trailing whitespace from the text of all column headers in a DataFrame

# %%
df=df.replace("�", "", regex=True) # Removed the symbol "�" from entire sheet

# %%
col1=['ProductName', 'CompanyName','BrandName','PrimaryCategory', 'SubCategory','ChemicalName']

df[col1] = df[col1].apply(lambda x: x.str.title()) # Converts text to Proper Case

# %%
df.isnull().sum() #Count the number of missing (null/NaN) values in each column
# Out:
# CDPHId                         0
# ProductName                    0
# CSFId                      33973
# CSF                        34398
# CompanyId                      0
# CompanyName                    0
# BrandName                    227
# PrimaryCategoryId              0
# PrimaryCategory                0
# SubCategoryId                  0
# SubCategory                    0
# CasId                          0
# CasNumber                   6476
# ChemicalId                     0
# ChemicalName                   0
# InitialDateReported            0
# MostRecentDateReported         0
# DiscontinuedDate          101715
# ChemicalCreatedAt              0
# ChemicalUpdatedAt              0
# ChemicalDateRemoved       111650
# ChemicalCount                  0
# dtype: int64

# %%
df=df.drop(columns=['DiscontinuedDate','ChemicalDateRemoved','CasId', 'CasNumber']) # Delected columns which having more null values

# %%
df.columns
# Out:
# Index(['CDPHId', 'ProductName', 'CSFId', 'CSF', 'CompanyId', 'CompanyName',
#        'BrandName', 'PrimaryCategoryId', 'PrimaryCategory', 'SubCategoryId',
#        'SubCategory', 'ChemicalId', 'ChemicalName', 'InitialDateReported',
#        'MostRecentDateReported', 'ChemicalCreatedAt', 'ChemicalUpdatedAt',
#        'ChemicalCount'],
#       dtype='object')

# %%
cols = ['InitialDateReported', 'MostRecentDateReported', 'ChemicalCreatedAt', 'ChemicalUpdatedAt']
df[cols] = df[cols].apply(pd.to_datetime, errors='coerce')  # covert all date column data type in to date time format

# %%
df.duplicated().sum() #Number of Duplicated rows
# Out:
# np.int64(257)

# %%
df=df.drop_duplicates() # Remove duplicated rows

# %%
df.shape # Dimensions of a DataFrame after removal of duplicate rows
# Out:
# (114378, 18)

# %%
df.isnull().sum()
# Out:
# CDPHId                        0
# ProductName                   0
# CSFId                     33728
# CSF                       34153
# CompanyId                     0
# CompanyName                   0
# BrandName                   227
# PrimaryCategoryId             0
# PrimaryCategory               0
# SubCategoryId                 0
# SubCategory                   0
# ChemicalId                    0
# ChemicalName                  0
# InitialDateReported           0
# MostRecentDateReported        0
# ChemicalCreatedAt             0
# ChemicalUpdatedAt             0
# ChemicalCount                 0
# dtype: int64

# %%
df['CSFId']=df['CSFId'].fillna('NA') 
df['CSF']=df['CSF'].fillna('NA') # Replacing missing CSFId and CSF with 'NA' value

# %%
df['BrandName']=df['BrandName'].fillna(df['BrandName'].mode()[0]) # Replacing missing brand name with mode value

# %%
df.isnull().sum()
# Out:
# CDPHId                    0
# ProductName               0
# CSFId                     0
# CSF                       0
# CompanyId                 0
# CompanyName               0
# BrandName                 0
# PrimaryCategoryId         0
# PrimaryCategory           0
# SubCategoryId             0
# SubCategory               0
# ChemicalId                0
# ChemicalName              0
# InitialDateReported       0
# MostRecentDateReported    0
# ChemicalCreatedAt         0
# ChemicalUpdatedAt         0
# ChemicalCount             0
# dtype: int64

# %%
df['ChemicalCount'].describe() #Statistical Summary of chemical count
# Out:
# count    114378.000000
# mean          1.288989
# std           0.636980
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           9.000000
# Name: ChemicalCount, dtype: float64

# %% [raw]
# Short Summary about Chemical Count
#
# 1.Most of product having only one chemical count
# 2.Chemical count varies from 0 to 9
# 3.Variation between one product chemical to another product chemical count is less

# %%
#importing library
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
#Univariate Analysis
# To find how the chemical count distribution
plt.figure(figsize=(8,4))
plt.hist(df['ChemicalCount'],bins=10,edgecolor='black',color='pink')
plt.title("Distribution of Chemical Count")
plt.xlabel("Chemical Count")
plt.ylabel("Frequency")
plt.show()

# %% [raw]
# Short conclusion from above histogram
# 1.Typical chemical count is low
# 2.There are some extreme/high values, but not many

# %%
#Top 5 company which producing more chemical based product
top5_company=df.groupby('CompanyName')['ChemicalName'].nunique().sort_values(ascending=False).head(5)
top5_df = top5_company.reset_index(name='Number of Chemicals')
fig = px.pie(top5_df,
             names='CompanyName',
             values='Number of Chemicals',
             title='Top 5 Companies by Number of Chemicals')
fig.update_traces(pull=[0.1, 0, 0, 0, 0]) # Pull first slice out
fig.update_layout(width=700, height=500)
fig.show()

# %% [raw]
# #short summary
# From the pie chart, it can be observed that Regis Corporation has the highest number of chemical-based products
# It is followed by Fisk Industries and Coty, which also show a high number of chemicals used in their products.

# %%
#Top 10 brand name which contain more chemicals
Top10_brand=df.groupby('BrandName')['ChemicalName'].nunique().sort_values(ascending=False).head(10)
Top10_brand_df = Top10_brand.reset_index(name='Number of Chemicals')
fig=px.bar(Top10_brand_df,x='BrandName',y='Number of Chemicals',color='BrandName',title='Top 10 Brand Name by No.of Chemicals')
fig.update_layout(width=900, height=500)
fig.show()

# %% [markdown]
# #Short Insight
#
# It is evident from the chart that Regis Design Line has more chemical ingredients than the other brands shown.

# %%
#Top 10 brand name which contain less chemicals
lowest10_brand=df.groupby('BrandName')['ChemicalName'].nunique().sort_values(ascending=True).head(10)
lowest10_brand_df = lowest10_brand.reset_index(name='Number of Chemicals')
fig=px.bar(lowest10_brand_df,x='Number of Chemicals',y='BrandName',color='BrandName',title='Top 10 Brand Name Having Less No.of Chemicals')
fig.update_layout(width=900, height=500)
fig.show()

# %% [raw]
# # Short Summary
# It can be observed that most brands rely on a single chemical ingredient.

# %%
# Top 10 brand products that contain the highest number of different chemicals.
Top10_brand_product=df.groupby(['BrandName','ProductName'])['ChemicalName'].nunique().sort_values(ascending=False).head(10)
top10_df = Top10_brand_product.reset_index(name='Number of Chemicals')
fig=px.treemap(top10_df,
                 path=['BrandName','ProductName'],
                 values='Number of Chemicals',
                 title='Top 10 brand products by Number of Chemicals')
fig.update_layout(width=1000, height=600)
fig.show()

# %% [raw]
# #Short summary
#
# According to the chart, the Curl Lock Conditioner product from Regis Design Line stands out for having the most chemical ingredients.

# %%
#Top 5 checmical used in most products
Top5_chemicals=df.groupby('ChemicalName')['ProductName'].nunique().sort_values(ascending=False).head(5)
Top5_chemicals_df=Top5_chemicals.reset_index(name='Number of product') 
fig=px.line(Top5_chemicals_df,x='ChemicalName',y='Number of product',
            title='Top 5 chemicals by products',
            markers=True)
fig.update_traces(marker=dict(symbol='star', size=10, color='red')) 
fig.update_traces(line=dict(color='green',width=4, dash='dash'))
fig.update_layout(width=1200,height=700)

# %% [raw]
# #Short Summary
# Titanium Dioxide appears as the most common chemical ingredient among the products.

# %%
# Step 1: Get top 5 categories
top_categories = df['PrimaryCategory'].value_counts().head(5).index

# Step 2: Filter dataset
df_top = df[df['PrimaryCategory'].isin(top_categories)]

# Step 3: Create pivot
pivot = df_top.pivot_table(
    index='PrimaryCategory',
    columns='SubCategory',
    values='ChemicalName',
    aggfunc='nunique'
).fillna(0)


# Step 4: Plot heatmap
plt.figure(figsize=(20,8))

sns.heatmap(
    pivot,
    cmap='coolwarm',
    annot=True,
    fmt='.0f',
    linewidths=0.5
)

plt.title('Top 5 Categories: Chemical Diversity Across SubCategories')
plt.xlabel('SubCategory')
plt.ylabel('Primary Category')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [raw]
# #Short summary
#
# -A few primary categories dominate in terms of chemical diversity -Skin Care products,Sun-Related Products
# -Certain subcategories contain significantly higher numbers of unique chemicals -Skin Moisturizers,Skin Cleanesers,facial cream,Sunscreen

# %%
#Trend of Reported Chemicals Over Time
df['Year'] = df['ChemicalCreatedAt'].dt.year  # Extracts the year from a datetime column
trend = df.groupby('Year').size().reset_index(name='Number of Chemicals')
fig = px.line(trend, x='Year', y='Number of Chemicals', markers=True)
fig.update_layout(width=1000, height=500, title='Trend of Reported Chemicals Over Time')
fig.update_traces(marker=dict(symbol='cross', size=10, color='green')) 
fig.update_traces(line=dict(color='cyan',width=4))
fig.show()

# %% [raw]
# #Short Summary
# There is a noticeable spike on year 2009 and drop on 2020

# %% [markdown]
# <h2 style="color: blue; text-decoration: underline;">
# Key Insights
# </h2>

# %% [raw]
# Visualization Key Insights
#
# 1.Regis Corporation has the highest number of chemical-based products among all brands analyzed.
# 2.It is evident from the chart that Regis Design Line has more chemical ingredients than the other brands shown.
# 3.The Curl Lock Conditioner product from Regis Design Line stands out for having the most chemical ingredients.
# 4.Titanium Dioxide appears as the most common chemical ingredient among the products.
# 5.Among all categories, Skin Care Products and Sun-Related Products show the greatest chemical diversity
# 6.Certain subcategories contain significantly higher numbers of unique chemicals -Skin Moisturizers,Skin Cleanesers,facial cream,Sunscreen
# 7.There is a notable spike in reported chemicals around 2009 Followed by a steady decline, reaching a low point in 2020

# %% [raw]
# Overall Conclustion
#
# 1.The majority of cosmetic products contain a relatively low number of chemicals, indicating simpler formulations for most items.
# 2.A small number of products exhibit significantly high chemical counts, suggesting the presence of more complex formulations.

# %% [raw]
# Recommendations
#
# 1.Identify and monitor frequently used chemicals for safety review
# 2.Pay extra attention to high-complexity products
# 3.Conduct deeper analysis on skin care and sun-related categories
